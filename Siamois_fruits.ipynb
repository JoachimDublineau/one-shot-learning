# %% [markdown]
# Dataset used: https://www.kaggle.com/moltean/fruits

# %%
from google.colab import drive
drive.mount('drive')
# Out:
# Drive already mounted at drive; to attempt to forcibly remount, call drive.mount("drive", force_remount=True).

# %%
# -*- coding: utf-8 -*-
"""Untitled1.ipynb

Automatically generated by Colaboratory.

Original file is located at
    https://colab.research.google.com/drive/1O_5jpeuCApyOLSeDH4uPCG-y_zw_iX4t
"""
from keras.datasets import cifar10
from keras.models import Sequential, Model
from keras.layers import Input, Flatten, Dense, Dropout, Lambda, Activation
from keras.layers import Conv2D, MaxPooling2D
from keras.optimizers import RMSprop, Adam
from keras import backend as K
from keras.utils.vis_utils import plot_model
from keras import regularizers
from keras.applications.vgg19 import VGG19
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator

import os
import random
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.metrics import accuracy_score

# %%
# paths to load datasets
dir_path = 'drive/My Drive/Fruits/'
data_path = dir_path + 'fruits-360_dataset/fruits-360/'
train_path = data_path + 'Training/'
test_path = data_path + 'Test/'

embedding_path = dir_path + 'embeddings/'

# %% [markdown]
# ## get data

# %%
################################################
############ data generation
################################################


def get_dir_images(data_path):
  """return the differents categories, the images in these categories, and the number of images per category"""
  listDir = sorted(os.listdir(data_path))
  lis = [7,13,14,16,26,33,34,39,54,59]
  size = []
  listFiles = []
  target = []
  target_name = []
  i = 0
  for d in np.array(listDir)[lis] :
    files = sorted(os.listdir(data_path+'/'+d))
    size.append(len(files))
    files = [data_path+'/'+d+'/'+f for f in files]
    target_name += [d] * len(files)
    target += [i] * len(files)
    i += 1
    listFiles += files
  return listFiles, target_name, np.array(target), size
  

def get_images(listFiles, input_shape=(100,100,3)):
  images = []
  for f in listFiles:
    img = image.load_img(f, target_size=input_shape)
    img = np.array(img)/255.
    images.append(img)
  return np.array(images)


def group_data(imgs, target):
  grouped_data = {}
  for i in range(10):
    grouped_data[i] = imgs[np.argwhere(target==i)[:,0]]
  return grouped_data

def get_batch(grouped_data, num_list):
  target = []
  batch = []
  data_ = grouped_data

  num_example = min([data_[i].shape[0] for i in num_list])
  print('getting {} examples'.format(num_example))
  for i in range(num_example):
    i1,i2 = np.random.choice(num_list,2, replace=False)
    i_index = np.random.choice(num_example,4, replace=False)
    batch += [[data_[i1][i_index[0]], data_[i1][i_index[1]]]]
    batch += [[data_[i1][i_index[2]], data_[i2][i_index[3]]]]
    target.append(1)
    target.append(0)
  return np.array(batch), np.array(target)

def get_test_batch(grouped_data, test_size, test_target, categ_target, k=10):#k-way one shot learning
  batch = [np.zeros((test_size*k, 100, 100, 3)) for i in range(2)]
  # batch = []
  target = [] # index of correct category
  num_list = test_target
  categ_list = categ_target
  data_ = grouped_data
  for i in range(test_size):
    i1 = np.random.choice(num_list)
    i1_index = np.random.choice(data_[i1].shape[0])
    batch[0][i*k:i*k+k,:] = np.repeat(data_[i1][i1_index][np.newaxis,:], k, axis=0)
    target.append(i1)
    for k_i in range(k):
      i2_index = np.random.choice(data_[categ_list[k_i]].shape[0])
      batch[1][i*k+k_i,:] = data_[categ_list[k_i]][i2_index]
      while categ_list[k_i]==i1 and i2_index == i1_index:
        i2_index = np.random.choice(data_[categ_list[k_i]].shape[0])
        batch[1][i*k+k_i,:] = data_[categ_list[k_i]][i2_index]
    
  return batch, target

# %% [markdown]
# ## create siamese model

# %%
num_class = 10
feature_dim = 3


################################################
############ Model Building
################################################

def euclidean_distance(vects):
    x, y = vects
    sum_square = K.sum(K.square(x - y), axis=1, keepdims=True)
    return K.sqrt(K.maximum(sum_square, K.epsilon()))

def eucl_dist_output_shape(shapes):
    shape1, shape2 = shapes
    return (shape1[0], 1)

def contrastive_loss(y_true, y_pred):
  '''Contrastive loss from Hadsell-et-al.'06
  http://yann.lecun.com/exdb/publis/pdf/hadsell-chopra-lecun-06.pdf
  '''
  margin = 5
  square_pred = K.square(y_pred)
  margin_square = K.square(K.maximum(margin - y_pred, 0))
  return K.mean(y_true * square_pred + (1 - y_true) * margin_square)

def get_siamese_model(input_shape, distance = 'l1'):
    
  left_input = Input(input_shape, name='input1')
  right_input = Input(input_shape, name='input2')
  

  model = Sequential()
  model.add(Conv2D(100, (3, 3), padding='same',
                  input_shape=input_shape))
  model.add(Activation('relu'))
  model.add(Conv2D(100, (3, 3), padding='same'))
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2)))
  model.add(Dropout(0.3))

  model.add(Conv2D(200, (3, 3), padding='same', kernel_regularizer=regularizers.l2(0.0001)))
  model.add(Activation('relu'))

  model.add(Conv2D(200, (3, 3), padding='same', kernel_regularizer=regularizers.l2(0.0001)))
  model.add(Activation('relu'))

  model.add(Conv2D(300, (3, 3), padding='same', kernel_regularizer=regularizers.l2(0.0001)))
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2)))
  model.add(Dropout(0.3))

  model.add(Flatten())

  # base_model.add(Dense(1024, activation='relu', name='dense1'))
  # base_model.add(Dropout(0.5, name='dropout1'))
  # base_model.add(Dense(512, activation='relu', name='dense2'))
  # base_model.add(Dropout(0.3, name='dropout2'))
  encoded_l = model(left_input)
  encoded_r = model(right_input)

  if distance == 'l1':
    L1_layer = Lambda(lambda tensors:K.abs(tensors[0] - tensors[1]))
    L1_distance = L1_layer([encoded_l, encoded_r])
    prediction = Dense(1,activation='sigmoid')(L1_distance)

    siamese_net = Model(inputs=[left_input,right_input],outputs=prediction)

  else:
    distance = Lambda(euclidean_distance,
                  output_shape=eucl_dist_output_shape)([encoded_l, encoded_r])

    siamese_net = Model([left_input,right_input], distance)
  return siamese_net


def accuracy(y_true, y_pred):
    '''Compute classification accuracy with a fixed threshold on distances.
    '''
    return K.mean(K.equal(y_true, K.cast(y_pred<0.5, y_true.dtype)))

def get_model_performance(model, batch, targets, val_batch, val_targets):
  y_pred = model.predict([batch[:, 0], batch[:, 1]])
  tr_acc = np.mean(((y_pred.ravel() < 0.5) == targets))
  y_pred = model.predict([val_batch[:, 0], val_batch[:, 1]])
  te_acc = np.mean(((y_pred.ravel() < 0.5) == val_targets))

  print('* Accuracy on training set: %0.2f%%' % (100 * tr_acc))
  print('* Accuracy on test set: %0.2f%%' % (100 * te_acc))

def get_one_shot_performance(model, data, distance):
  test_size = 10240
  batch, target = data.get_test_batch(test_size, test_num_list, all_num_list, k=10)
  y_pre = model.predict(batch)
  if distance == 'l1':
    pre = np.argmax(y_pre.reshape(-1,len(all_num_list)),axis=1)
  else:
    pre = np.argmin(y_pre.reshape(-1,len(all_num_list)),axis=1)
  return accuracy_score(target, pre)

################################################
############ Feature Model
################################################

def get_feature_model(model):
  feature_model = Model(inputs=model.input, outputs=model.layers[3].input)
  return feature_model

def get_features(feature_model, data):
  data_sz = data.shape[0]
  if data_sz%2 == 0:
    features = feature_model.predict([data[:data_sz//2], data[data_sz//2:]])
    return np.concatenate((features[0], features[1]), axis = 0)
  else:
    features = feature_model.predict([data[:data_sz//2], data[data_sz//2:-1]])
    features = np.concatenate((features[0], features[1]), axis = 0)
    last_feature = feature_model.predict([data[-1][np.newaxis,:], data[-1][np.newaxis,:]])[0]
    return np.concatenate((features, last_feature), axis = 0)


def get_features_(feature_model, data):
  features = feature_model.predict([data, data])
  return features[0]

def get_labeled_features(feature_model, data, list_labels):
  features = np.array([]).reshape((0,feature_dim))
  targets = []
  for i in list_labels:
    data_ = data.grouped_data[i]
    features_ = get_features_(feature_model, data_)
    print(features_)
    features = np.concatenate((features, features_), axis = 0)
    targets_ = [i] * features_.shape[0]
    targets += targets_
  return features, targets

################################################
############ Plot
################################################

def plot_history(history, with_val = False):
  history_dict = history.history
  loss_values = history_dict['loss']
  if with_val:
    val_loss_values = history_dict['val_loss']
  epochs = range(1, len(loss_values) + 1)
  plt.figure(figsize=(15,5))
  plt.subplot(1,2,1)
  plt.plot(epochs, loss_values, label='Training loss')
  if with_val:
    plt.plot(epochs, val_loss_values, label='Validation loss')
  plt.title('Training loss')
  plt.xlabel('Epochs')
  plt.ylabel('Loss')
  plt.legend()

  acc = history_dict['accuracy']
  if with_val:
    val_acc = history_dict['val_accuracy']
  plt.subplot(1,2,2)
  plt.plot(epochs, acc, label='Training acc')
  if with_val:
    plt.plot(epochs, val_acc, label='Validation acc')
  plt.title('Training acc')
  plt.xlabel('Epochs')
  plt.ylabel('acc')
  plt.legend()
  
  plt.show()

def plot_feature(features, labels):
  if feature_dim == 2:
    fig, ax = plt.subplots()
    scatter = ax.scatter(features[: ,0], features[:,1], c=labels, s=3)
    legend1 = ax.legend(*scatter.legend_elements(),
                        loc="upper right", title="Class")
    ax.add_artist(legend1)
  else:
    fig = plt.figure()
    ax = Axes3D(fig)
    scatter = ax.scatter(features[:,0], features[:,1], features[:,2], c=labels, s=3)
    legend1 = ax.legend(*scatter.legend_elements(), title="Class")
    ax.add_artist(legend1)
  plt.show()

def plot_and_save_feature(features, labels, i):
  if feature_dim == 2:
    fig, ax = plt.subplots()
    scatter = ax.scatter(features[: ,0], features[:,1], c=labels, s=3)
    legend1 = ax.legend(*scatter.legend_elements(),
                        loc="upper right", title="Class")
    ax.add_artist(legend1)
  else:
    fig = plt.figure()
    ax = Axes3D(fig)
    ax.scatter(features[:,0], features[:,1], features[:,2], c=labels)
    legend1 = ax.legend(*scatter.legend_elements(), title="Class")
    ax.add_artist(legend1)
  plt.savefig('/content/drive/My Drive/'+str(i)+'.png')
  plt.show()

# %% [markdown]
# ## load data

# %%
images = np.load(data_path+'images2.npy')
test_images = np.load(data_path+'test_images2.npy')
targets = np.load(data_path+'targets2.npy')
test_targets = np.load(data_path+'test_targets2.npy')

# listFiles, target_name, targets, size = get_dir_images(train_path)
# test_listFiles, test_target_name, test_targets, size = get_dir_images(train_path)

# images = get_images(listFiles, input_shape = input_shape)
# test_images = get_images(test_listFiles, input_shape = input_shape)

# %%
set(target_name)
# Out:
# {'Apple Red 1',
#  'Apricot',
#  'Avocado',
#  'Banana',
#  'Cherry 1',
#  'Clementine',
#  'Cocos',
#  'Grape Blue',
#  'Lemon',
#  'Mango'}

# %%
train_num_list = list(range(5))
val_num_list = list(range(5))
test_num_list = list(range(5,10))
all_num_list = list(range(10))
input_shape = (32, 32, 3)

grouped_data = group_data(images, targets)
test_grouped_data = group_data(test_images, test_targets)

batch, target = get_batch(grouped_data, train_num_list)
test_batch, test_target = get_batch(test_grouped_data, test_num_list)

################################################
################################################

epochs = 150
batch_size = 156

distance = 'euclidean'
# distance = 'l1'
model= get_siamese_model(input_shape, distance)

opt = RMSprop()
# opt = Adam()
model.compile(loss=contrastive_loss, optimizer=opt, metrics=[accuracy])

history = model.fit([batch[:, 0], batch[:, 1]], target ,batch_size=batch_size,
          epochs=epochs, validation_split=0.3)

plot_history(history, with_val=True)

model.evaluate([test_batch[:,0],test_batch[:,1]],test_target)
# Out:
# getting 427 examples
# getting 490 examples
# Train on 597 samples, validate on 257 samples
# Epoch 1/150
# 597/597 [==============================] - 3s 5ms/step - loss: 12.0403 - accuracy: 0.5142 - val_loss: 12.0109 - val_accuracy: 0.4981
# Epoch 2/150
# 597/597 [==============================] - 1s 2ms/step - loss: 9.9472 - accuracy: 0.4992 - val_loss: 11.3568 - val_accuracy: 0.5214
150
# 597/597 [==============================] - 1s 2ms/step - loss: 3.5743 - accuracy: 0.4992 - val_loss: 3.1308 - val_accuracy: 0.9105
# Epoch 60/150
# 597/597 [==============================] - 1s 2ms/step - loss: 3.7754 - accuracy: 0.4992 - val_loss: 5.0117 - val_accuracy: 0.8054
# Epoch 61/150
# 597/597 [==============================] - 1s 2ms/step - loss: 3.9564 - accuracy: 0.4992 - val_loss: 4.3877 - val_accuracy: 0.8444
# Epoch 62/150
# 597/597 [==============================] - 1s 2ms/step - loss: 3.7143 - accuracy: 0.4992 - val_loss: 4.4616 - val_accuracy: 0.8794
# Epoch 63/150
# 597/597 [==============================] - 1s 2ms/step - loss: 3.6917 - accuracy: 0.4992 - val_loss: 4.2083 - val_accuracy: 0.8482
# Epoch 64/150
# 597/597 [==============================] - 1s 2ms/step - loss: 3.5400 - accuracy: 0.4992 - val_loss: 3.1523 - val_accuracy: 0.9066
# Epoch 65/150
# 597/597 [==============================] - 1s 2ms/step - loss: 3.9716 - accuracy: 0.4992 - val_loss: 4.0064 - val_accuracy: 0.8949
# Epoch 66/150
# 597/597 [==============================] - 1s 2ms/step - loss: 3.6248 - accuracy: 0.4992 - val_loss: 3.9374 - val_accuracy: 0.8794
# Epoch 67/150
# 597/597 [==============================] - 1s 2ms/step - loss: 3.6003 - accuracy: 0.4992 - val_loss: 3.3695 - val_accuracy: 0.8949
# Epoch 68/150
# 597/597 [==============================] - 1s 2ms/step - loss: 3.5545 - accuracy: 0.4992 - val_loss: 3.5912 - val_accuracy: 0.8677
# Epoch 69/150
# 597/597 [==============================] - 1s 2ms/step - loss: 3.7059 - accuracy: 0.4992 - val_loss: 5.0763 - val_accuracy: 0.6848
# Epoch 70/150
# 597/597 [==============================] - 1s 2ms/step - loss: 3.8761 - accuracy: 0.4992 - val_loss: 4.6075 - val_accuracy: 0.8872
# Epoch 71/150
# 597/597 [==============================] - 1s 2ms/step - loss: 3.5601 - accuracy: 0.4992 - val_loss: 3.9432 - val_accuracy: 0.8833
# Epoch 72/150
# 597/597 [==============================] - 1s 2ms/step - loss: 3.7470 - accuracy: 0.4992 - val_loss: 4.3978 - val_accuracy: 0.8482
# Epoch 73/150
# 597/597 [==============================] - 1s 2ms/step - loss: 3.8002 - accuracy: 0.4992 - val_loss: 4.5095 - val_accuracy: 0.8755
# Epoch 74/150
# 597/597 [==============================] - 1s 2ms/step - loss: 3.5672 - accuracy: 0.4992 - val_loss: 4.5329 - val_accuracy: 0.8833
# Epoch 75/150
# 597/597 [==============================] - 1s 2ms/step - loss: 3.5807 - accuracy: 0.4992 - val_loss: 3.2807 - val_accuracy: 0.8949
# Epoch 76/150
# 597/597 [==============================] - 1s 2ms/step - loss: 3.6215 - accuracy: 0.4992 - val_loss: 3.5226 - val_accuracy: 0.8872
# Epoch 77/150
# 597/597 [==============================] - 1s 2ms/step - loss: 3.6483 - accuracy: 0.4992 - val_loss: 3.6669 - val_accuracy: 0.8833
# Epoch 78/150
# 597/597 [==============================] - 1s 2ms/step - loss: 3.5572 - accuracy: 0.4992 - val_loss: 3.7589 - val_accuracy: 0.8949
# Epoch 79/150
# 597/597 [==============================] - 1s 2ms/step - loss: 3.7738 - accuracy: 0.4992 - val_loss: 4.4885 - val_accuracy: 0.8016
# Epoch 80/150
# 597/597 [==============================] - 1s 2ms/step - loss: 3.7269 - accuracy: 0.4992 - val_loss: 4.1054 - val_accuracy: 0.8794
# Epoch 81/150
# 597/597 [==============================] - 1s 2ms/step - loss: 3.5800 - accuracy: 0.4992 - val_loss: 3.9406 - val_accuracy: 0.8872
# Epoch 82/150
# 597/597 [==============================] - 1s 2ms/step - loss: 3.5177 - accuracy: 0.4992 - val_loss: 4.7753 - val_accuracy: 0.8949
# Epoch 83/150
# 597/597 [==============================] - 1s 2ms/step - loss: 3.5681 - accuracy: 0.4992 - val_loss: 4.0945 - val_accuracy: 0.9183
# Epoch 84/150
# 597/597 [==============================] - 1s 2ms/step - loss: 3.5208 - accuracy: 0.4992 - val_loss: 3.1398 - val_accuracy: 0.9066
# Epoch 85/150
# 597/597 [==============================] - 1s 2ms/step - loss: 3.5148 - accuracy: 0.4992 - val_loss: 4.1629 - val_accuracy: 0.9105
# Epoch 86/150
# 597/597 [==============================] - 1s 2ms/step - loss: 3.5698 - accuracy: 0.4992 - val_loss: 5.0664 - val_accuracy: 0.8638
# Epoch 87/150
# 597/597 [==============================] - 1s 2ms/step - loss: 3.6434 - accuracy: 0.4992 - val_loss: 3.1628 - val_accuracy: 0.8794
# Epoch 88/150
# 597/597 [==============================] - 1s 2ms/step - loss: 3.6328 - accuracy: 0.4992 - val_loss: 4.3739 - val_accuracy: 0.8132
# Epoch 89/150
# 597/597 [==============================] - 1s 2ms/step - loss: 3.5465 - accuracy: 0.4992 - val_loss: 3.6812 - val_accuracy: 0.9183
# Epoch 90/150
# 597/597 [==============================] - 1s 2ms/step - loss: 3.4906 - accuracy: 0.4992 - val_loss: 4.1883 - val_accuracy: 0.9144
# Epoch 91/150
# 597/597 [==============================] - 1s 2ms/step - loss: 3.4537 - accuracy: 0.4992 - val_loss: 3.5769 - val_accuracy: 0.8677
# Epoch 92/150
# 597/597 [==============================] - 1s 2ms/step - loss: 3.5029 - accuracy: 0.4992 - val_loss: 2.9825 - val_accuracy: 0.8988
# Epoch 93/150
# 597/597 [==============================] - 1s 2ms/step - loss: 3.4715 - accuracy: 0.4992 - val_loss: 4.0761 - val_accuracy: 0.9183
# Epoch 94/150
# 597/597 [==============================] - 1s 2ms/step - loss: 3.4687 - accuracy: 0.4992 - val_loss: 3.0619 - val_accuracy: 0.8872
# Epoch 95/150
# 597/597 [==============================] - 1s 2ms/step - loss: 3.7244 - accuracy: 0.4992 - val_loss: 3.7063 - val_accuracy: 0.7393
# Epoch 96/150
# 597/597 [==============================] - 1s 2ms/step - loss: 3.5436 - accuracy: 0.4992 - val_loss: 3.7063 - val_accuracy: 0.8872
# Epoch 97/150
# 597/597 [==============================] - 1s 2ms/step - loss: 3.3661 - accuracy: 0.4992 - val_loss: 3.2552 - val_accuracy: 0.9183
# Epoch 98/150
# 597/597 [==============================] - 1s 2ms/step - loss: 3.4565 - accuracy: 0.4992 - val_loss: 4.2411 - val_accuracy: 0.8988
# Epoch 99/150
# 597/597 [==============================] - 1s 2ms/step - loss: 3.4422 - accuracy: 0.4992 - val_loss: 3.8679 - val_accuracy: 0.8327
# Epoch 100/150
# 597/597 [==============================] - 1s 2ms/step - loss: 3.3624 - accuracy: 0.4992 - val_loss: 3.3725 - val_accuracy: 0.8988
# Epoch 101/150
# 597/597 [==============================] - 1s 2ms/step - loss: 3.4608 - accuracy: 0.4992 - val_loss: 3.6877 - val_accuracy: 0.8988
# Epoch 102/150
# 597/597 [==============================] - 1s 2ms/step - loss: 3.3880 - accuracy: 0.4992 - val_loss: 3.1208 - val_accuracy: 0.8988
# Epoch 103/150
# 597/597 [==============================] - 1s 2ms/step - loss: 3.4259 - accuracy: 0.4992 - val_loss: 3.6846 - val_accuracy: 0.6615
# Epoch 104/150
# 597/597 [==============================] - 1s 2ms/step - loss: 3.6983 - accuracy: 0.4992 - val_loss: 2.3717 - val_accuracy: 0.8366
# Epoch 105/150
# 597/597 [==============================] - 1s 2ms/step - loss: 3.5191 - accuracy: 0.4992 - val_loss: 3.2822 - val_accuracy: 0.8988
# Epoch 106/150
# 597/597 [==============================] - 1s 2ms/step - loss: 3.2455 - accuracy: 0.4992 - val_loss: 3.0008 - val_accuracy: 0.8988
# Epoch 107/150
# 597/597 [==============================] - 1s 2ms/step - loss: 3.2511 - accuracy: 0.4992 - val_loss: 3.6301 - val_accuracy: 0.9183
# Epoch 108/150
# 597/597 [==============================] - 1s 2ms/step - loss: 3.2622 - accuracy: 0.4992 - val_loss: 2.9840 - val_accuracy: 0.9144
# Epoch 109/150
# 597/597 [==============================] - 1s 2ms/step - loss: 3.4485 - accuracy: 0.4992 - val_loss: 3.9165 - val_accuracy: 0.9066
# Epoch 110/150
# 597/597 [==============================] - 1s 2ms/step - loss: 3.2874 - accuracy: 0.4992 - val_loss: 2.9666 - val_accuracy: 0.9066
# Epoch 111/150
# 597/597 [==============================] - 1s 2ms/step - loss: 3.2751 - accuracy: 0.4992 - val_loss: 3.2619 - val_accuracy: 0.9105
# Epoch 112/150
# 597/597 [==============================] - 1s 2ms/step - loss: 3.3206 - accuracy: 0.4992 - val_loss: 3.1815 - val_accuracy: 0.9066
# Epoch 113/150
# 597/597 [==============================] - 1s 2ms/step - loss: 3.1870 - accuracy: 0.4992 - val_loss: 2.9531 - val_accuracy: 0.9066
# Epoch 114/150
# 597/597 [==============================] - 1s 2ms/step - loss: 3.2340 - accuracy: 0.4992 - val_loss: 3.0546 - val_accuracy: 0.9222
# Epoch 115/150
# 597/597 [==============================] - 1s 2ms/step - loss: 3.2742 - accuracy: 0.4992 - val_loss: 4.0367 - val_accuracy: 0.9222
# Epoch 116/150
# 597/597 [==============================] - 1s 2ms/step - loss: 3.3343 - accuracy: 0.4992 - val_loss: 3.1441 - val_accuracy: 0.8171
# Epoch 117/150
# 597/597 [==============================] - 1s 2ms/step - loss: 3.2745 - accuracy: 0.4992 - val_loss: 2.5900 - val_accuracy: 0.8482
# Epoch 118/150
# 597/597 [==============================] - 1s 2ms/step - loss: 3.2979 - accuracy: 0.4992 - val_loss: 3.5473 - val_accuracy: 0.9144
# Epoch 119/150
# 597/597 [==============================] - 1s 2ms/step - loss: 3.4306 - accuracy: 0.4992 - val_loss: 3.1484 - val_accuracy: 0.9222
# Epoch 120/150
# 597/597 [==============================] - 1s 2ms/step - loss: 3.2677 - accuracy: 0.4992 - val_loss: 2.5686 - val_accuracy: 0.9144
# Epoch 121/150
# 597/597 [==============================] - 1s 2ms/step - loss: 3.1778 - accuracy: 0.4992 - val_loss: 3.1417 - val_accuracy: 0.9339
# Epoch 122/150
# 597/597 [==============================] - 1s 2ms/step - loss: 3.2082 - accuracy: 0.4992 - val_loss: 2.5221 - val_accuracy: 0.9183
# Epoch 123/150
# 597/597 [==============================] - 1s 2ms/step - loss: 3.3127 - accuracy: 0.4992 - val_loss: 2.7947 - val_accuracy: 0.8872
# Epoch 124/150
# 597/597 [==============================] - 1s 2ms/step - loss: 3.3701 - accuracy: 0.4992 - val_loss: 3.8746 - val_accuracy: 0.8833
# Epoch 125/150
# 597/597 [==============================] - 1s 2ms/step - loss: 3.3285 - accuracy: 0.4992 - val_loss: 3.1463 - val_accuracy: 0.9066
# Epoch 126/150
# 597/597 [==============================] - 1s 2ms/step - loss: 3.3186 - accuracy: 0.4992 - val_loss: 3.8229 - val_accuracy: 0.9261
# Epoch 127/150
# 597/597 [==============================] - 1s 2ms/step - loss: 3.2485 - accuracy: 0.4992 - val_loss: 2.7757 - val_accuracy: 0.9416
# Epoch 128/150
# 597/597 [==============================] - 1s 2ms/step - loss: 3.1824 - accuracy: 0.4992 - val_loss: 2.7768 - val_accuracy: 0.9416
# Epoch 129/150
# 597/597 [==============================] - 1s 2ms/step - loss: 3.2967 - accuracy: 0.4992 - val_loss: 2.7214 - val_accuracy: 0.8833
# Epoch 130/150
# 597/597 [==============================] - 1s 2ms/step - loss: 3.2123 - accuracy: 0.4992 - val_loss: 3.3766 - val_accuracy: 0.9339
# Epoch 131/150
# 597/597 [==============================] - 1s 2ms/step - loss: 3.2073 - accuracy: 0.4992 - val_loss: 3.1182 - val_accuracy: 0.9377
# Epoch 132/150
# 597/597 [==============================] - 1s 2ms/step - loss: 3.1616 - accuracy: 0.4992 - val_loss: 3.1139 - val_accuracy: 0.9144
# Epoch 133/150
# 597/597 [==============================] - 1s 2ms/step - loss: 3.2946 - accuracy: 0.4992 - val_loss: 2.3581 - val_accuracy: 0.9105
# Epoch 134/150
# 597/597 [==============================] - 1s 2ms/step - loss: 3.3681 - accuracy: 0.4992 - val_loss: 2.9799 - val_accuracy: 0.9455
# Epoch 135/150
# 597/597 [==============================] - 1s 2ms/step - loss: 3.3016 - accuracy: 0.4992 - val_loss: 3.6482 - val_accuracy: 0.9377
# Epoch 136/150
# 597/597 [==============================] - 1s 2ms/step - loss: 3.1965 - accuracy: 0.4992 - val_loss: 2.9336 - val_accuracy: 0.9572
# Epoch 137/150
# 597/597 [==============================] - 1s 2ms/step - loss: 3.1887 - accuracy: 0.4992 - val_loss: 2.6746 - val_accuracy: 0.8872
# Epoch 138/150
# 597/597 [==============================] - 1s 2ms/step - loss: 3.3631 - accuracy: 0.4992 - val_loss: 1.9665 - val_accuracy: 0.7549
# Epoch 139/150
# 597/597 [==============================] - 1s 2ms/step - loss: 3.5859 - accuracy: 0.4992 - val_loss: 2.7096 - val_accuracy: 0.9261
# Epoch 140/150
# 597/597 [==============================] - 1s 2ms/step - loss: 3.1577 - accuracy: 0.4992 - val_loss: 3.0889 - val_accuracy: 0.9261
# Epoch 141/150
# 597/597 [==============================] - 1s 2ms/step - loss: 3.1627 - accuracy: 0.4992 - val_loss: 3.7142 - val_accuracy: 0.9261
# Epoch 142/150
# 597/597 [==============================] - 1s 2ms/step - loss: 3.2524 - accuracy: 0.4992 - val_loss: 2.7375 - val_accuracy: 0.9222
# Epoch 143/150
# 597/597 [==============================] - 1s 2ms/step - loss: 3.1220 - accuracy: 0.4992 - val_loss: 3.2838 - val_accuracy: 0.9455
# Epoch 144/150
# 597/597 [==============================] - 1s 2ms/step - loss: 3.1597 - accuracy: 0.4992 - val_loss: 3.4791 - val_accuracy: 0.9533
# Epoch 145/150
# 597/597 [==============================] - 1s 2ms/step - loss: 3.2603 - accuracy: 0.4992 - val_loss: 3.3859 - val_accuracy: 0.9300
# Epoch 146/150
# 597/597 [==============================] - 1s 2ms/step - loss: 3.1409 - accuracy: 0.4992 - val_loss: 2.9133 - val_accuracy: 0.8833
# Epoch 147/150
# 597/597 [==============================] - 1s 2ms/step - loss: 3.2238 - accuracy: 0.4992 - val_loss: 3.1964 - val_accuracy: 0.8833
# Epoch 148/150
# 597/597 [==============================] - 1s 2ms/step - loss: 3.1998 - accuracy: 0.4992 - val_loss: 2.0683 - val_accuracy: 0.8599
# Epoch 149/150
# 597/597 [==============================] - 1s 2ms/step - loss: 3.2124 - accuracy: 0.4992 - val_loss: 2.6221 - val_accuracy: 0.9183
# Epoch 150/150
# 597/597 [==============================] - 1s 2ms/step - loss: 3.1025 - accuracy: 0.4992 - val_loss: 2.6249 - val_accuracy: 0.8638
# 980/980 [==============================] - 1s 770us/step
# [3.4949019889442288, 0.782653061467774]

# %% [markdown]
# ## save data

# %%
np.save(data_path+'images2.npy', images)
np.save(data_path+'test_images2.npy', test_images)
np.save(data_path+'targets2.npy', targets)
np.save(data_path+'test_targets2.npy', test_targets)

# %% [markdown]
# ## save model

# %%
model.save(dir_path+'fruits.h5')
